# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="data/processed/data.yaml",
    epochs=30,
    imgsz=640,
    batch=8,
    project="results",
    name="yolo_baseline"
)
